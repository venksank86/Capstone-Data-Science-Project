# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://ibm.box.com/shared/static/9gegpsmnsoo25ikkbl4qzlvlyjbgxs5x.png" width = 400> </a>
#
# <h1 align=center><font size = 5>Learning FourSquare API with Python</font></h1>

# %% [markdown]
# ## Introduction
#
# In this lab, you will learn in details how to make calls to the Foursquare API for different purposes. You will learn how to construct a URL to send a request to the API to search for a specific type of venues, to explore a particular venue, to explore a Foursquare user, to explore a geographical location, and to get trending venues around a location. Also, you will learn how to use the visualization library, Folium, to visualize the results.

# %% [markdown]
# ## Table of Contents
#
# 1. <a href="#item1">Foursquare API Search Function</a>
# 2. <a href="#item2">Explore a Given Venue</a>
# 3. <a href="#item3">Explore a User</a>
# 4. <a href="#item4">Foursquare API Explore Function</a>
# 5. <a href="#item5">Get Trending Venues</a>

# %% [markdown]
# ### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %% [markdown]
# ##### Make sure that you have created a Foursquare developer account and have your credentials handy

# %%
CLIENT_ID = 'LAAFIKWSIOAZLUJXOTYGS3T4WQJCCFSX3FO3NMIL00BX5BNB' # your Foursquare ID
CLIENT_SECRET = 'ZDSPHLMEEMDA5XKGGWTYXUT35KYLGR4RPLBXNLHYGQ1TUHNT' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 50
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: LAAFIKWSIOAZLUJXOTYGS3T4WQJCCFSX3FO3NMIL00BX5BNB
# CLIENT_SECRET:ZDSPHLMEEMDA5XKGGWTYXUT35KYLGR4RPLBXNLHYGQ1TUHNT

# %% [markdown]
# #### Let's again assume that you are staying at the Conrad hotel. So let's start by converting the Contrad Hotel's address to its latitude and longitude coordinates.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>foursquare_agent</em>, as shown below.

# %%
address = 'AMB Cinemas Hyderabad'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 17.457321 78.3634764

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ## 1. Search for a specific venue category
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# #### Now, let's assume that it is lunch time, and you are craving Italian food. So, let's define a query to search for Italian food that is within 500 metres from the Conrad Hotel.

# %%
search_query = 'Restaurant'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %% [markdown]
# #### Define the corresponding URL

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=LAAFIKWSIOAZLUJXOTYGS3T4WQJCCFSX3FO3NMIL00BX5BNB&client_secret=ZDSPHLMEEMDA5XKGGWTYXUT35KYLGR4RPLBXNLHYGQ1TUHNT&ll=17.457321,78.3634764&v=20180604&query=Restaurant&radius=5000&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e8f2ada1a4b0a001b901f03'},
#  'response': {'venues': [{'id': '4dc404efd164eb9c9fca0e8c',
#     'name': 'Gardenia Bar & Restaurant',
#     'location': {'lat': 17.459301,
#      'lng': 78.36647,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.459301,
#        'lng': 78.36647}],
#      'distance': 386,
#      'postalCode': '500084',
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Hyderabad 500084', 'Telangana', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d117941735',
#       'name': 'Beer Garden',
#       'pluralName': 'Beer Gardens',
#       'shortName': 'Beer Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '5bdbfdfd1a2925003247dd49',
#     'name': 'Swadesh Multi-cuisine Restaurant',
#     'location': {'address': 'Kothaguda',
#      'lat': 17.457851,
#      'lng': 78.365844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.457851,
#        'lng': 78.365844}],
#      'distance': 258,
#      'postalCode': '500084',
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'TG',
#      'country': 'India',
#      'formattedAddress': ['Kothaguda', 'Hyderabad 500084', 'TG', 'India']},
#     'categories': [{'id': '54135bf5e4b08f3d2429dfe0',
#       'name': 'Multicuisine Indian Restaurant',
#       'pluralName': 'Multicuisine Indian Restaurants',
#       'shortName': 'Multicuisine Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '515d384ce4b0d7a8c1412e28',
#     'name': 'Mirch Masala Restaurant',
#     'location': {'address': 'mirch masala',
#      'crossStreet': 'kothaguda junction',
#      'lat': 17.455738165189928,
#      'lng': 78.36629258180274,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.455738165189928,
#        'lng': 78.36629258180274}],
#      'distance': 347,
#      'cc': 'IN',
#      'city': 'Hyderabad, Andhra Pradesh',
#      'state': 'andra pradesh',
#      'country': 'India',
#      'formattedAddress': ['mirch masala (kothaguda junction)',
#       'Hyderabad, Andhra Pradesh',
#       'andra pradesh',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '518e6f1d498e1abaef4e8642',
#     'name': 'Teja Multicuisine Restaurant',
#     'location': {'lat': 17.4604856595397,
#      'lng': 78.3671432454139,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.4604856595397,
#        'lng': 78.3671432454139}],
#      'distance': 525,
#      'postalCode': '500084',
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Hyderabad 500084', 'Telangana', 'India']},
#     'categories': [],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '539b1989498ef1b1c9bd60ca',
#     'name': 'Athidhyam Restaurant',
#     'location': {'lat': 17.461315309190255,
#      'lng': 78.36665371470033,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.461315309190255,
#        'lng': 78.36665371470033}],
#      'distance': 558,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '502d1288e4b0f9a2dc332f18',
#     'name': 'Hyderabad Restaurant',
#     'location': {'address': 'Madhapur',
#      'crossStreet': 'Madhapur Main Rd',
#      'lat': 17.443801743943645,
#      'lng': 78.38729174869157,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.443801743943645,
#        'lng': 78.38729174869157}],
#      'distance': 2942,
#      'postalCode': '500081',
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Madhapur (Madhapur Main Rd)',
#       'Hyderabad 500081',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '518e6fb5498ebdadd17f71d2',
#     'name': 'Teja Multicuisine Restaurant',
#     'location': {'address': 'Kondapur',
#      'lat': 17.4519232101738,
#      'lng': 78.3671432454139,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.4519232101738,
#        'lng': 78.3671432454139}],
#      'distance': 716,
#      'postalCode': '500084',
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Kondapur',
#       'Hyderabad 500084',
#       'Telangana',
#       'India']},
#     'categories': [],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '5a7329bbc876c81f275890d9',
#     'name': 'Rangrez Fine Dine Restaurant',
#     'location': {'address': 'First Floor',
#      'crossStreet': 'Biodiversity Circle',
#      'lat': 17.428822,
#      'lng': 78.373924,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.428822,
#        'lng': 78.373924}],
#      'distance': 3360,
#      'postalCode': '500081',
#      'cc': 'IN',
#      'neighborhood': 'Gachibowli',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['First Floor (Biodiversity Circle)',
#       'Hyderabad 500081',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '54135bf5e4b08f3d2429dfdd',
#       'name': 'North Indian Restaurant',
#       'pluralName': 'North Indian Restaurants',
#       'shortName': 'North Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4db2efb6cda1c57c823a29c9',
#     'name': 'Wings N Fries Restaurant',
#     'location': {'address': 'Adj. Chevrolet Showroom',
#      'crossStreet': 'Kondapur',
#      'lat': 17.462993001106604,
#      'lng': 78.36861058854163,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.462993001106604,
#        'lng': 78.36861058854163}],
#      'distance': 834,
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Adj. Chevrolet Showroom (Kondapur)',
#       'Hyderabad',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4da1db3c9935a0938bc7a86f',
#     'name': 'Haveli Restaurant & Bar',
#     'location': {'address': 'Kondapur',
#      'lat': 17.462941458090466,
#      'lng': 78.36865281741878,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.462941458090466,
#        'lng': 78.36865281741878}],
#      'distance': 832,
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Kondapur', 'Hyderabad', 'Telangana', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '54339ebb498e648f00e85637',
#     'name': 'forest restaurant',
#     'location': {'address': 'Sri  Ram  Nagar',
#      'lat': 17.460132668256666,
#      'lng': 78.35428002672458,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.460132668256666,
#        'lng': 78.35428002672458}],
#      'distance': 1025,
#      'postalCode': '500072',
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Sri  Ram  Nagar',
#       'Hyderabad 500072',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '52af3b773cf9994f4e043c03',
#       'name': 'Szechuan Restaurant',
#       'pluralName': 'Szechuan Restaurants',
#       'shortName': 'Szechuan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '51f2a3bd498e051a94d45d43',
#     'name': 'Rasagolla Restaurant',
#     'location': {'lat': 17.4709288350573,
#      'lng': 78.36496471305954,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.4709288350573,
#        'lng': 78.36496471305954}],
#      'distance': 1523,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4fb9f3e1e4b06ef132b07e06',
#     'name': 'Swarna Tantra Restaurant',
#     'location': {'lat': 17.44961507611003,
#      'lng': 78.35261304939529,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.44961507611003,
#        'lng': 78.35261304939529}],
#      'distance': 1437,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '51ebf7f4498edf54257e2423',
#     'name': 'gokul bar &  restaurant',
#     'location': {'lat': 17.467780741322414,
#      'lng': 78.37224277972314,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.467780741322414,
#        'lng': 78.37224277972314}],
#      'distance': 1490,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4e0e22f5a56208c4ea9a85a0',
#       'name': 'Distillery',
#       'pluralName': 'Distilleries',
#       'shortName': 'Distillery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '592057dc5d0fea5ae1d84dc3',
#     'name': 'Suraj  Bar & Restaurant',
#     'location': {'address': 'hi-tech city junction',
#      'lat': 17.45319410273503,
#      'lng': 78.38073876015713,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.45319410273503,
#        'lng': 78.38073876015713}],
#      'distance': 1889,
#      'postalCode': '500084',
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['hi-tech city junction',
#       'Hyderabad 500084',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '5406d4ca498e28c333b2ba3c',
#     'name': 'Signature Restaurant',
#     'location': {'address': '8-3-940/1, ASR Enclave, Ameetpet cross roads (old), Yellareddy Guda',
#      'crossStreet': 'Yellareddy Guda',
#      'lat': 17.459719962912082,
#      'lng': 78.34848940372467,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.459719962912082,
#        'lng': 78.34848940372467}],
#      'distance': 1613,
#      'cc': 'IN',
#      'city': 'Hyderābād',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['8-3-940/1, ASR Enclave, Ameetpet cross roads (old), Yellareddy Guda (Yellareddy Guda)',
#       'Hyderābād',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '56d7f145498e774201d4f0ac',
#     'name': 'kanishk bar & restaurant',
#     'location': {'address': 'Kondapur',
#      'lat': 17.472456,
#      'lng': 78.364196,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.472456,
#        'lng': 78.364196}],
#      'distance': 1686,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['Kondapur', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '565d5c48498e474323e74fcd',
#     'name': 'Shayana kebabs and Restaurant',
#     'location': {'lat': 17.472497,
#      'lng': 78.364362,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.472497,
#        'lng': 78.364362}],
#      'distance': 1691,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '54018377498e13815e0dadf2',
#     'name': 'Kritunga Restaurant',
#     'location': {'address': 'Near DLF Building',
#      'crossStreet': 'Gachibowli',
#      'lat': 17.44631422255068,
#      'lng': 78.35282420134314,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.44631422255068,
#        'lng': 78.35282420134314}],
#      'distance': 1667,
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Near DLF Building (Gachibowli)',
#       'Hyderabad',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '531098c0498e697f0312c1e9',
#     'name': 'Rockdeal Bar and Restaurant',
#     'location': {'address': 'Above Hazel Ice Cream',
#      'crossStreet': 'Indira Nagar',
#      'lat': 17.441614178113753,
#      'lng': 78.35866951849522,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.441614178113753,
#        'lng': 78.35866951849522}],
#      'distance': 1821,
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Above Hazel Ice Cream (Indira Nagar)',
#       'Hyderabad',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '567665e8498eadfaaa41b8bb',
#     'name': 'Paradise Restaurant',
#     'location': {'lat': 17.44257,
#      'lng': 78.356273,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.44257,
#        'lng': 78.356273}],
#      'distance': 1811,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '54135bf5e4b08f3d2429dfe6',
#       'name': 'Hyderabadi Restaurant',
#       'pluralName': 'Hyderabadi Restaurants',
#       'shortName': 'Hyderabadi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '539b000c498e0d932e6f04ed',
#     'name': 'Suraj Restaurant and Bar',
#     'location': {'lat': 17.440584743054554,
#      'lng': 78.3634256973835,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.440584743054554,
#        'lng': 78.3634256973835}],
#      'distance': 1863,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4f58d5fbe4b0cd6f8d31aa93',
#     'name': 'Aviyal Veg Restaurant',
#     'location': {'lat': 17.447123759721936,
#      'lng': 78.37829818448482,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.447123759721936,
#        'lng': 78.37829818448482}],
#      'distance': 1940,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '57113254498e83b7be5815af',
#     'name': 'Madhushala Bar & Restaurant',
#     'location': {'crossStreet': 'Hi-tech City Road',
#      'lat': 17.446719,
#      'lng': 78.378141,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.446719,
#        'lng': 78.378141}],
#      'distance': 1953,
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Hi-tech City Road',
#       'Hyderabad',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4d691735de28224b6d653ebe',
#     'name': 'Suraj Bar & Restaurant',
#     'location': {'address': 'Verizon Capital, Above KGN Xerox,',
#      'crossStreet': 'Near Gachibowli Cross Roads',
#      'lat': 17.453243610087316,
#      'lng': 78.38075206253708,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.453243610087316,
#        'lng': 78.38075206253708}],
#      'distance': 1889,
#      'cc': 'IN',
#      'neighborhood': 'Gachibowli',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Verizon Capital, Above KGN Xerox, (Near Gachibowli Cross Roads)',
#       'Hyderabad',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '5b659292a4ba7c002c5bb35c',
#     'name': 'Ikea Restaurant',
#     'location': {'lat': 17.438938,
#      'lng': 78.375937,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.438938,
#        'lng': 78.375937}],
#      'distance': 2436,
#      'postalCode': '500081',
#      'cc': 'IN',
#      'city': 'Rajendra Nagar',
#      'state': 'TG',
#      'country': 'India',
#      'formattedAddress': ['Rajendra Nagar 500081', 'TG', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d1c6941735',
#       'name': 'Scandinavian Restaurant',
#       'pluralName': 'Scandinavian Restaurants',
#       'shortName': 'Scandinavian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/scandinavian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '583845a29900e6088cf72252',
#     'name': 'Spiceit Restaurant',
#     'location': {'lat': 17.447374,
#      'lng': 78.378716,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.447374,
#        'lng': 78.378716}],
#      'distance': 1960,
#      'postalCode': '500081',
#      'cc': 'IN',
#      'city': '海德拉巴',
#      'state': '泰倫迦納邦',
#      'country': 'India',
#      'formattedAddress': ['海德拉巴 500081', '泰倫迦納邦', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '5177ab3a498e1f75b62c8d85',
#     'name': 'Amity Multicuisine Restaurant',
#     'location': {'address': 'Vinayaka Nagar',
#      'crossStreet': 'Gachibowli',
#      'lat': 17.441615752052822,
#      'lng': 78.3586973866798,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.441615752052822,
#        'lng': 78.3586973866798}],
#      'distance': 1820,
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Vinayaka Nagar (Gachibowli)',
#       'Hyderabad',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4dd62caffa76ad96d104ffb9',
#     'name': 'Techies ( Solis ) Restaurant',
#     'location': {'lat': 17.454214075210697,
#      'lng': 78.38305892739807,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.454214075210697,
#        'lng': 78.38305892739807}],
#      'distance': 2108,
#      'postalCode': '500081',
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Hyderabad 500081', 'Telangana', 'India']},
#     'categories': [],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4fcb7504e4b067457c768cf6',
#     'name': 'All Seasons Multicuisine Restaurant',
#     'location': {'address': '2nd Floor, Opp SBR Gateway',
#      'crossStreet': 'HiTech City Road',
#      'lat': 17.447249078237927,
#      'lng': 78.37824263192825,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.447249078237927,
#        'lng': 78.37824263192825}],
#      'distance': 1927,
#      'postalCode': '500081',
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['2nd Floor, Opp SBR Gateway (HiTech City Road)',
#       'Hyderabad 500081',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '5239d9d111d20bef50fabe70',
#     'name': "Mallu's restaurant",
#     'location': {'lat': 17.438349807635,
#      'lng': 78.3591616619378,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.438349807635,
#        'lng': 78.3591616619378}],
#      'distance': 2160,
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Hyderabad', 'Telangana', 'India']},
#     'categories': [],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4dd929a3d22d38ef4311e530',
#     'name': 'Paradise Restaurant',
#     'location': {'address': 'Beside Shilpa Kalavedika, Opp. Cyber Tower',
#      'crossStreet': 'HiTech City',
#      'lat': 17.45050421098169,
#      'lng': 78.37910814779563,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.45050421098169,
#        'lng': 78.37910814779563}],
#      'distance': 1825,
#      'postalCode': '500084',
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Beside Shilpa Kalavedika, Opp. Cyber Tower (HiTech City)',
#       'Hyderabad 500084',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4c911d749d5cbfb7caaf9b1d',
#     'name': 'Windows Restaurant',
#     'location': {'address': 'Hitech city',
#      'crossStreet': 'Madhapur',
#      'lat': 17.442857,
#      'lng': 78.380607,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.442857,
#        'lng': 78.380607}],
#      'distance': 2429,
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Hitech city (Madhapur)',
#       'Hyderabad',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1e1931735',
#       'name': 'Arcade',
#       'pluralName': 'Arcades',
#       'shortName': 'Arcade',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/arcade_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '524c2ec6498e8db880abc439',
#     'name': 'Mallus Restaurant',
#     'location': {'lat': 17.435190427413662,
#      'lng': 78.36373127993781,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.435190427413662,
#        'lng': 78.36373127993781}],
#      'distance': 2463,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4c7d26d45af8b60c7aa58e10',
#     'name': 'KFC restaurAnt',
#     'location': {'address': 'Hitech city',
#      'lat': 17.442549823326193,
#      'lng': 78.38160350773667,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.442549823326193,
#        'lng': 78.38160350773667}],
#      'distance': 2531,
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Hitech city', 'Hyderabad', 'Telangana', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d14c941735',
#       'name': 'Wings Joint',
#       'pluralName': 'Wings Joints',
#       'shortName': 'Wings',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/wings_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '58e5f9a480e1af764824dda5',
#     'name': 'Messeleistro Restaurant',
#     'location': {'address': 'Hitex',
#      'crossStreet': 'Hitec City',
#      'lat': 17.472739,
#      'lng': 78.383034,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.472739,
#        'lng': 78.383034}],
#      'distance': 2694,
#      'postalCode': '500081',
#      'cc': 'IN',
#      'city': 'Rajendra Nagar',
#      'state': 'TG',
#      'country': 'India',
#      'formattedAddress': ['Hitex (Hitec City)',
#       'Rajendra Nagar 500081',
#       'TG',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '501b8b68e4b03c7b5dc436bf',
#     'name': 'swarna taara restaurant',
#     'location': {'lat': 17.432893607084935,
#      'lng': 78.36422021014445,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.432893607084935,
#        'lng': 78.36422021014445}],
#      'distance': 2720,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4db67d316a23c31a033fb043',
#     'name': 'Amaravathi Restaurant',
#     'location': {'lat': 17.433430552482605,
#      'lng': 78.3693140745163,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.433430552482605,
#        'lng': 78.3693140745163}],
#      'distance': 2730,
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Hyderabad', 'Telangana', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '5a3e6c12c666666f89f095ca',
#     'name': 'Malgudi Restaurant',
#     'location': {'address': 'Metro Pillar No 10, Opposite to Karachi Bakery',
#      'lat': 17.445364,
#      'lng': 78.386215,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.445364,
#        'lng': 78.386215}],
#      'distance': 2757,
#      'postalCode': '500081',
#      'cc': 'IN',
#      'neighborhood': 'Madhapur',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Metro Pillar No 10, Opposite to Karachi Bakery',
#       'Hyderabad 500081',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '56694fbe498ed1f38cfda35c',
#     'name': 'ABHIRUCHI RESTAURANT',
#     'location': {'lat': 17.445741526225632,
#      'lng': 78.38581972425916,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.445741526225632,
#        'lng': 78.38581972425916}],
#      'distance': 2700,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '54135bf5e4b08f3d2429dfe5',
#       'name': 'Andhra Restaurant',
#       'pluralName': 'Andhra Restaurants',
#       'shortName': 'Andhra',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4b86888bf964a520578e31e3',
#     'name': 'Grand Four Seasons',
#     'location': {'address': '2nd Floor, SMR Vinay Technopolis, Opposite Capital IQ',
#      'crossStreet': 'Kondapur',
#      'lat': 17.45788521909287,
#      'lng': 78.37167396246235,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.45788521909287,
#        'lng': 78.37167396246235}],
#      'distance': 872,
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['2nd Floor, SMR Vinay Technopolis, Opposite Capital IQ (Kondapur)',
#       'Hyderabad',
#       'Telangana',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '5545dbed498e6aa68a5fae19',
#     'name': 'Hitech Nanking Restaurant',
#     'location': {'address': 'Madhapur',
#      'lat': 17.445290320802602,
#      'lng': 78.38569196265624,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.445290320802602,
#        'lng': 78.38569196265624}],
#      'distance': 2712,
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Madhapur', 'Hyderabad', 'Telangana', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '57e3a663cd1069727f7fdf7e',
#     'name': 'Happyness Restaurant',
#     'location': {'lat': 17.44699,
#      'lng': 78.38907,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.44699,
#        'lng': 78.38907}],
#      'distance': 2951,
#      'postalCode': '500081',
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Hyderabad 500081', 'Telangana', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '505c7f60e4b012e7c84cd9b6',
#     'name': 'Shivani Restaurant',
#     'location': {'lat': 17.432006911783706,
#      'lng': 78.37163721970103,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.432006911783706,
#        'lng': 78.37163721970103}],
#      'distance': 2948,
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Hyderabad', 'Telangana', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '585a34000acb6a62e465c4f1',
#     'name': '9 Grill Restaurant And Bar',
#     'location': {'lat': 17.431406,
#      'lng': 78.37328,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.431406,
#        'lng': 78.37328}],
#      'distance': 3066,
#      'postalCode': '500081',
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Hyderabad 500081', 'Telangana', 'India']},
#     'categories': [{'id': '54135bf5e4b08f3d2429dfe5',
#       'name': 'Andhra Restaurant',
#       'pluralName': 'Andhra Restaurants',
#       'shortName': 'Andhra',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4f53b63de4b06025ea3fd874',
#     'name': 'masala grill restaurant',
#     'location': {'lat': 17.443278794721184,
#      'lng': 78.38741950831084,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.443278794721184,
#        'lng': 78.38741950831084}],
#      'distance': 2984,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4ee37e6a9adf3982fe8bf8a2',
#     'name': 'Hong Kong',
#     'location': {'address': 'Gachibowli',
#      'lat': 17.444452256660934,
#      'lng': 78.36296454381745,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.444452256660934,
#        'lng': 78.36296454381745}],
#      'distance': 1433,
#      'cc': 'IN',
#      'city': 'Hyderabad',
#      'state': 'Telangana',
#      'country': 'India',
#      'formattedAddress': ['Gachibowli', 'Hyderabad', 'Telangana', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4f519256e4b02d0eb2795586',
#     'name': 'hari priya Restaurant',
#     'location': {'lat': 17.452132711271265,
#      'lng': 78.39208540323034,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.452132711271265,
#        'lng': 78.39208540323034}],
#      'distance': 3092,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '52fb989a498e8c5b1460a4b6',
#     'name': 'Fisher Men Restaurant',
#     'location': {'lat': 17.47439193725586,
#      'lng': 78.38813018798828,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.47439193725586,
#        'lng': 78.38813018798828}],
#      'distance': 3234,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False},
#    {'id': '4ec68a5b775bf65c02495829',
#     'name': 'Bommarillu Restaurant',
#     'location': {'lat': 17.49615038345264,
#      'lng': 78.36343125343801,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 17.49615038345264,
#        'lng': 78.36343125343801}],
#      'distance': 4322,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586440801',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)

dataframe.head(100)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                           id                                 name  \
# 0   4dc404efd164eb9c9fca0e8c            Gardenia Bar & Restaurant
# 1   5bdbfdfd1a2925003247dd49     Swadesh Multi-cuisine Restaurant
# 2   515d384ce4b0d7a8c1412e28              Mirch Masala Restaurant
# 3   518e6f1d498e1abaef4e8642         Teja Multicuisine Restaurant
# 4   539b1989498ef1b1c9bd60ca                 Athidhyam Restaurant
# 5   502d1288e4b0f9a2dc332f18                 Hyderabad Restaurant
# 6   518e6fb5498ebdadd17f71d2         Teja Multicuisine Restaurant
# 7   5a7329bbc876c81f275890d9         Rangrez Fine Dine Restaurant
# 8   4db2efb6cda1c57c823a29c9             Wings N Fries Restaurant
# 9   4da1db3c9935a0938bc7a86f              Haveli Restaurant & Bar
# 10  54339ebb498e648f00e85637                    forest restaurant
# 11  51f2a3bd498e051a94d45d43                 Rasagolla Restaurant
# 12  4fb9f3e1e4b06ef132b07e06             Swarna Tantra Restaurant
# 13  51ebf7f4498edf54257e2423              gokul bar &  restaurant
# 14  592057dc5d0fea5ae1d84dc3              Suraj  Bar & Restaurant
# 15  5406d4ca498e28c333b2ba3c                 Signature Restaurant
# 16  56d7f145498e774201d4f0ac             kanishk bar & restaurant
# 17  565d5c48498e474323e74fcd        Shayana kebabs and Restaurant
# 18  54018377498e13815e0dadf2                  Kritunga Restaurant
# 19  531098c0498e697f0312c1e9          Rockdeal Bar and Restaurant
# 20  567665e8498eadfaaa41b8bb                  Paradise Restaurant
# 21  539b000c498e0d932e6f04ed             Suraj Restaurant and Bar
# 22  4f58d5fbe4b0cd6f8d31aa93                Aviyal Veg Restaurant
# 23  57113254498e83b7be5815af          Madhushala Bar & Restaurant
# 24  4d691735de28224b6d653ebe               Suraj Bar & Restaurant
# 25  5b659292a4ba7c002c5bb35c                      Ikea Restaurant
# 26  583845a29900e6088cf72252                   Spiceit Restaurant
# 27  5177ab3a498e1f75b62c8d85        Amity Multicuisine Restaurant
# 28  4dd62caffa76ad96d104ffb9         Techies ( Solis ) Restaurant
# 29  4fcb7504e4b067457c768cf6  All Seasons Multicuisine Restaurant
# 30  5239d9d111d20bef50fabe70                   Mallu's restaurant
# 31  4dd929a3d22d38ef4311e530                  Paradise Restaurant
# 32  4c911d749d5cbfb7caaf9b1d                   Windows Restaurant
# 33  524c2ec6498e8db880abc439                    Mallus Restaurant
# 34  4c7d26d45af8b60c7aa58e10                       KFC restaurAnt
# 35  58e5f9a480e1af764824dda5              Messeleistro Restaurant
# 36  501b8b68e4b03c7b5dc436bf              swarna taara restaurant
# 37  4db67d316a23c31a033fb043                Amaravathi Restaurant
# 38  5a3e6c12c666666f89f095ca                   Malgudi Restaurant
# 39  56694fbe498ed1f38cfda35c                 ABHIRUCHI RESTAURANT
# 40  4b86888bf964a520578e31e3                   Grand Four Seasons
# 41  5545dbed498e6aa68a5fae19            Hitech Nanking Restaurant
# 42  57e3a663cd1069727f7fdf7e                 Happyness Restaurant
# 43  505c7f60e4b012e7c84cd9b6                   Shivani Restaurant
# 44  585a34000acb6a62e465c4f1           9 Grill Restaurant And Bar
# 45  4f53b63de4b06025ea3fd874              masala grill restaurant
# 46  4ee37e6a9adf3982fe8bf8a2                            Hong Kong
# 47  4f519256e4b02d0eb2795586                hari priya Restaurant
# 48  52fb989a498e8c5b1460a4b6                Fisher Men Restaurant
# 49  4ec68a5b775bf65c02495829                Bommarillu Restaurant
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d117941735', 'name': 'B...  v-1586440801    False
# 1   [{'id': '54135bf5e4b08f3d2429dfe0', 'name': 'M...  v-1586440801    False
# 2   [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 3                                                  []  v-1586440801    False
# 4   [{'id': '4bf58dd8d48988d147941735', 'name': 'D...  v-1586440801    False
# 5   [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 6                                                  []  v-1586440801    False
# 7   [{'id': '54135bf5e4b08f3d2429dfdd', 'name': 'N...  v-1586440801    False
# 8   [{'id': '4bf58dd8d48988d16c941735', 'name': 'B...  v-1586440801    False
# 9   [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 10  [{'id': '52af3b773cf9994f4e043c03', 'name': 'S...  v-1586440801    False
# 11  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 12  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 13  [{'id': '4e0e22f5a56208c4ea9a85a0', 'name': 'D...  v-1586440801    False
# 14  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1586440801    False
# 15  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...  v-1586440801    False
# 16  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1586440801    False
# 17  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1586440801    False
# 18  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 19  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1586440801    False
# 20  [{'id': '54135bf5e4b08f3d2429dfe6', 'name': 'H...  v-1586440801    False
# 21  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1586440801    False
# 22  [{'id': '4bf58dd8d48988d1d3941735', 'name': 'V...  v-1586440801    False
# 23  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...  v-1586440801    False
# 24  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 25  [{'id': '4bf58dd8d48988d1c6941735', 'name': 'S...  v-1586440801    False
# 26  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 27  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 28                                                 []  v-1586440801    False
# 29  [{'id': '4bf58dd8d48988d115941735', 'name': 'M...  v-1586440801    False
# 30                                                 []  v-1586440801    False
# 31  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 32  [{'id': '4bf58dd8d48988d1e1931735', 'name': 'A...  v-1586440801    False
# 33  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 34  [{'id': '4bf58dd8d48988d14c941735', 'name': 'W...  v-1586440801    False
# 35  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1586440801    False
# 36  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 37  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 38  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 39  [{'id': '54135bf5e4b08f3d2429dfe5', 'name': 'A...  v-1586440801    False
# 40  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 41  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1586440801    False
# 42  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 43  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1586440801    False
# 44  [{'id': '54135bf5e4b08f3d2429dfe5', 'name': 'A...  v-1586440801    False
# 45  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 46  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1586440801    False
# 47  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1586440801    False
# 48  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1586440801    False
# 49  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1586440801    False
#
#     location.lat  location.lng  \
# 0      17.459301     78.366470
# 1      17.457851     78.365844
# 2      17.455738     78.366293
# 3      17.460486     78.367143
# 4      17.461315     78.366654
# 5      17.443802     78.387292
# 6      17.451923     78.367143
# 7      17.428822     78.373924
# 8      17.462993     78.368611
# 9      17.462941     78.368653
# 10     17.460133     78.354280
# 11     17.470929     78.364965
# 12     17.449615     78.352613
# 13     17.467781     78.372243
# 14     17.453194     78.380739
# 15     17.459720     78.348489
# 16     17.472456     78.364196
# 17     17.472497     78.364362
# 18     17.446314     78.352824
# 19     17.441614     78.358670
# 20     17.442570     78.356273
# 21     17.440585     78.363426
# 22     17.447124     78.378298
# 23     17.446719     78.378141
# 24     17.453244     78.380752
# 25     17.438938     78.375937
# 26     17.447374     78.378716
# 27     17.441616     78.358697
# 28     17.454214     78.383059
# 29     17.447249     78.378243
# 30     17.438350     78.359162
# 31     17.450504     78.379108
# 32     17.442857     78.380607
# 33     17.435190     78.363731
# 34     17.442550     78.381604
# 35     17.472739     78.383034
# 36     17.432894     78.364220
# 37     17.433431     78.369314
# 38     17.445364     78.386215
# 39     17.445742     78.385820
# 40     17.457885     78.371674
# 41     17.445290     78.385692
# 42     17.446990     78.389070
# 43     17.432007     78.371637
# 44     17.431406     78.373280
# 45     17.443279     78.387420
# 46     17.444452     78.362965
# 47     17.452133     78.392085
# 48     17.474392     78.388130
# 49     17.496150     78.363431
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 17.459301, 'lng':...                386
# 1   [{'label': 'display', 'lat': 17.457851, 'lng':...                258
# 2   [{'label': 'display', 'lat': 17.45573816518992...                347
# 3   [{'label': 'display', 'lat': 17.4604856595397,...                525
# 4   [{'label': 'display', 'lat': 17.46131530919025...                558
# 5   [{'label': 'display', 'lat': 17.44380174394364...               2942
# 6   [{'label': 'display', 'lat': 17.4519232101738,...                716
# 7   [{'label': 'display', 'lat': 17.428822, 'lng':...               3360
# 8   [{'label': 'display', 'lat': 17.46299300110660...                834
# 9   [{'label': 'display', 'lat': 17.46294145809046...                832
# 10  [{'label': 'display', 'lat': 17.46013266825666...               1025
# 11  [{'label': 'display', 'lat': 17.4709288350573,...               1523
# 12  [{'label': 'display', 'lat': 17.44961507611003...               1437
# 13  [{'label': 'display', 'lat': 17.46778074132241...               1490
# 14  [{'label': 'display', 'lat': 17.45319410273503...               1889
# 15  [{'label': 'display', 'lat': 17.45971996291208...               1613
# 16  [{'label': 'display', 'lat': 17.472456, 'lng':...               1686
# 17  [{'label': 'display', 'lat': 17.472497, 'lng':...               1691
# 18  [{'label': 'display', 'lat': 17.44631422255068...               1667
# 19  [{'label': 'display', 'lat': 17.44161417811375...               1821
# 20  [{'label': 'display', 'lat': 17.44257, 'lng': ...               1811
# 21  [{'label': 'display', 'lat': 17.44058474305455...               1863
# 22  [{'label': 'display', 'lat': 17.44712375972193...               1940
# 23  [{'label': 'display', 'lat': 17.446719, 'lng':...               1953
# 24  [{'label': 'display', 'lat': 17.45324361008731...               1889
# 25  [{'label': 'display', 'lat': 17.438938, 'lng':...               2436
# 26  [{'label': 'display', 'lat': 17.447374, 'lng':...               1960
# 27  [{'label': 'display', 'lat': 17.44161575205282...               1820
# 28  [{'label': 'display', 'lat': 17.45421407521069...               2108
# 29  [{'label': 'display', 'lat': 17.44724907823792...               1927
# 30  [{'label': 'display', 'lat': 17.438349807635, ...               2160
# 31  [{'label': 'display', 'lat': 17.45050421098169...               1825
# 32  [{'label': 'display', 'lat': 17.442857, 'lng':...               2429
# 33  [{'label': 'display', 'lat': 17.43519042741366...               2463
# 34  [{'label': 'display', 'lat': 17.44254982332619...               2531
# 35  [{'label': 'display', 'lat': 17.472739, 'lng':...               2694
# 36  [{'label': 'display', 'lat': 17.43289360708493...               2720
# 37  [{'label': 'display', 'lat': 17.43343055248260...               2730
# 38  [{'label': 'display', 'lat': 17.445364, 'lng':...               2757
# 39  [{'label': 'display', 'lat': 17.44574152622563...               2700
# 40  [{'label': 'display', 'lat': 17.45788521909287...                872
# 41  [{'label': 'display', 'lat': 17.44529032080260...               2712
# 42  [{'label': 'display', 'lat': 17.44699, 'lng': ...               2951
# 43  [{'label': 'display', 'lat': 17.43200691178370...               2948
# 44  [{'label': 'display', 'lat': 17.431406, 'lng':...               3066
# 45  [{'label': 'display', 'lat': 17.44327879472118...               2984
# 46  [{'label': 'display', 'lat': 17.44445225666093...               1433
# 47  [{'label': 'display', 'lat': 17.45213271127126...               3092
# 48  [{'label': 'display', 'lat': 17.47439193725586...               3234
# 49  [{'label': 'display', 'lat': 17.49615038345264...               4322
#
#    location.postalCode location.cc              location.city location.state  \
# 0               500084          IN                  Hyderabad      Telangana
# 1               500084          IN                  Hyderabad             TG
# 2                  NaN          IN  Hyderabad, Andhra Pradesh  andra pradesh
# 3               500084          IN                  Hyderabad      Telangana
# 4                  NaN          IN                        NaN            NaN
# 5               500081          IN                  Hyderabad      Telangana
# 6               500084          IN                  Hyderabad      Telangana
# 7               500081          IN                  Hyderabad      Telangana
# 8                  NaN          IN                  Hyderabad      Telangana
# 9                  NaN          IN                  Hyderabad      Telangana
# 10              500072          IN                  Hyderabad      Telangana
# 11                 NaN          IN                        NaN            NaN
# 12                 NaN          IN                        NaN            NaN
# 13                 NaN          IN                        NaN            NaN
# 14              500084          IN                  Hyderabad      Telangana
# 15                 NaN          IN                  Hyderābād      Telangana
# 16                 NaN          IN                        NaN            NaN
# 17                 NaN          IN                        NaN            NaN
# 18                 NaN          IN                  Hyderabad      Telangana
# 19                 NaN          IN                  Hyderabad      Telangana
# 20                 NaN          IN                        NaN            NaN
# 21                 NaN          IN                        NaN            NaN
# 22                 NaN          IN                        NaN            NaN
# 23                 NaN          IN                  Hyderabad      Telangana
# 24                 NaN          IN                  Hyderabad      Telangana
# 25              500081          IN             Rajendra Nagar             TG
# 26              500081          IN                       海德拉巴          泰倫迦納邦
# 27                 NaN          IN                  Hyderabad      Telangana
# 28              500081          IN                  Hyderabad      Telangana
# 29              500081          IN                  Hyderabad      Telangana
# 30                 NaN          IN                  Hyderabad      Telangana
# 31              500084          IN                  Hyderabad      Telangana
# 32                 NaN          IN                  Hyderabad      Telangana
# 33                 NaN          IN                        NaN            NaN
# 34                 NaN          IN                  Hyderabad      Telangana
# 35              500081          IN             Rajendra Nagar             TG
# 36                 NaN          IN                        NaN            NaN
# 37                 NaN          IN                  Hyderabad      Telangana
# 38              500081          IN                  Hyderabad      Telangana
# 39                 NaN          IN                        NaN            NaN
# 40                 NaN          IN                  Hyderabad      Telangana
# 41                 NaN          IN                  Hyderabad      Telangana
# 42              500081          IN                  Hyderabad      Telangana
# 43                 NaN          IN                  Hyderabad      Telangana
# 44              500081          IN                  Hyderabad      Telangana
# 45                 NaN          IN                        NaN            NaN
# 46                 NaN          IN                  Hyderabad      Telangana
# 47                 NaN          IN                        NaN            NaN
# 48                 NaN          IN                        NaN            NaN
# 49                 NaN          IN                        NaN            NaN
#
#    location.country                          location.formattedAddress  \
# 0             India               [Hyderabad 500084, Telangana, India]
# 1             India           [Kothaguda, Hyderabad 500084, TG, India]
# 2             India  [mirch masala (kothaguda junction), Hyderabad,...
# 3             India               [Hyderabad 500084, Telangana, India]
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                         Gachibowli
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#            location.crossStreet location.neighborhood
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2            kothaguda junction                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
# 5              Madhapur Main Rd                   NaN
# 6                           NaN                   NaN
# 7           Biodiversity Circle            Gachibowli
# 8                      Kondapur                   NaN
# 9                           NaN                   NaN
# 10                          NaN                   NaN
# 11                          NaN                   NaN
# 12                          NaN                   NaN
# 13                          NaN                   NaN
# 14                          NaN                   NaN
# 15              Yellareddy Guda                   NaN
# 16                          NaN                   NaN
# 17                          NaN                   NaN
# 18                   Gachibowli                   NaN
# 19                 Indira Nagar                   NaN
# 20                          NaN                   NaN
# 21                          NaN                   NaN
# 22                          NaN                   NaN
# 23            Hi-tech City Road                   NaN
# 24  Near Gachibowli Cross Roads            Gachibowli
# 25                          NaN                   NaN
# 26                          NaN                   NaN
# 27                   Gachibowli                   NaN
# 28                          NaN                   NaN
# 29             HiTech City Road                   NaN
# 30                          NaN                   NaN
# 31                  HiTech City                   NaN
# 32                     Madhapur                   NaN
# 33                          NaN                   NaN
# 34                          NaN                   NaN
# 35                   Hitec City                   NaN
# 36                          NaN                   NaN
# 37                          NaN                   NaN
# 38                          NaN              Madhapur
# 39                          NaN                   NaN
# 40                     Kondapur                   NaN
# 41                          NaN                   NaN
# 42                          NaN                   NaN
# 43                          NaN                   NaN
# 44                          NaN                   NaN
# 45                          NaN                   NaN
# 46                          NaN                   NaN
# 47                          NaN                   NaN
# 48                          NaN                   NaN
# 49                          NaN                   NaN

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

#Build a new data frame with filtered Columns
df_new = dataframe_filtered[['name','categories','lat','lng','distance','postalCode','id']]
df_new['likes']          = 0
df_new['rating']         = 0
df_new['type']           = '' 

df_new["categories"]     = df_new["categories"].str.upper()
df_new
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                    name                      categories  \
# 0             Gardenia Bar & Restaurant                     BEER GARDEN
# 1      Swadesh Multi-cuisine Restaurant  MULTICUISINE INDIAN RESTAURANT
# 2               Mirch Masala Restaurant               INDIAN RESTAURANT
# 3          Teja Multicuisine Restaurant                            None
# 4                  Athidhyam Restaurant                           DINER
# 5                  Hyderabad Restaurant               INDIAN RESTAURANT
# 6          Teja Multicuisine Restaurant                            None
# 7          Rangrez Fine Dine Restaurant         NORTH INDIAN RESTAURANT
# 8              Wings N Fries Restaurant                    BURGER JOINT
# 9               Haveli Restaurant & Bar               INDIAN RESTAURANT
# 10                    forest restaurant             SZECHUAN RESTAURANT
# 11                 Rasagolla Restaurant               INDIAN RESTAURANT
# 12             Swarna Tantra Restaurant               INDIAN RESTAURANT
# 13              gokul bar &  restaurant                      DISTILLERY
# 14              Suraj  Bar & Restaurant                             BAR
# 15                 Signature Restaurant            FAST FOOD RESTAURANT
# 16             kanishk bar & restaurant                             BAR
# 17        Shayana kebabs and Restaurant                      RESTAURANT
# 18                  Kritunga Restaurant               INDIAN RESTAURANT
# 19          Rockdeal Bar and Restaurant                             BAR
# 20                  Paradise Restaurant           HYDERABADI RESTAURANT
# 21             Suraj Restaurant and Bar                             BAR
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='Yellow',
    popup='AMB Mall',
    fill = True,
    fill_color = 'Yellow',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='Red',
        popup=label,
        fill = True,
        fill_color='Red',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Filter Based on Vegan or Pure Veg Resturants
df_fil_veg             = df_new
df_fil_veg['Pure Veg'] = df_new['categories'].str.contains('VEGAN')
#Build the Index
df_pure_veg = df_fil_veg[(df_fil_veg['Pure Veg'] == True)]

df_pure_veg

## Add this to the existing Map with a different colour

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(df_pure_veg.lat, df_pure_veg.lng, df_pure_veg.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='Green',
        popup=label,
        fill = True,
        fill_color='Green',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Loop Through Each Resturant and find the no of likes for that restuarant
for i in range(len(df_new)) :
    venue_id = df_new.loc[i,"id"]
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    try:
        df_new.loc[ i, "likes"]  = result['response']['venue']['likes']['count']    
    except:
        df_new.loc[ i, "likes"]  = 0
    try:       
        df_new.loc[ i, "rating"] = result['response']['venue']['rating']
    except:
        df_new.loc[ i, "rating"]  = 0   
    try:
        df_new.loc[ i, "type"] = result['response']['venue']['categories'][0]['pluralName']
    except:
        df_new.loc[ i, "type"] = 'Multi-Cuisine' 
df_new
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
# Out:
#                                    name                      categories  \
# 0             Gardenia Bar & Restaurant                     BEER GARDEN
# 1      Swadesh Multi-cuisine Restaurant  MULTICUISINE INDIAN RESTAURANT
# 2               Mirch Masala Restaurant               INDIAN RESTAURANT
# 3          Teja Multicuisine Restaurant                            None
# 4                  Athidhyam Restaurant                           DINER
# 5                  Hyderabad Restaurant               INDIAN RESTAURANT
# 6          Teja Multicuisine Restaurant                            None
# 7          Rangrez Fine Dine Restaurant         NORTH INDIAN RESTAURANT
# 8              Wings N Fries Restaurant                    BURGER JOINT
# 9               Haveli Restaurant & Bar               INDIAN RESTAURANT
# 10                    forest restaurant             SZECHUAN RESTAURANT
# 11                 Rasagolla Restaurant               INDIAN RESTAURANT
# 12             Swarna Tantra Restaurant               INDIAN RESTAURANT
# 13              gokul bar &  restaurant                      DISTILLERY
# 14              Suraj  Bar & Restaurant                             BAR
# 15                 Signature Restaurant            FAST FOOD RESTAURANT
# 16             kanishk bar & restaurant                             BAR
# 17        Shayana kebabs and Restaurant                      RESTAURANT
# 18                  Kritunga Restaurant               INDIAN RESTAURANT
# 19          Rockdeal Bar and Restaurant                             BAR
# 20                  Paradise Restaurant           HYDERABADI RESTAURANT
# 21             Suraj Restaurant and Bar                             BAR
# 22                Aviyal Veg Restaurant   VEGETARIAN / VEGAN RESTAURANT
# 23          Madhushala Bar & Restaurant                             PUB
# 24               Suraj Bar & Restaurant               INDIAN RESTAURANT
# 25                      Ikea Restaurant         SCANDINAVIAN RESTAURANT
# 26                   Spiceit Restaurant               INDIAN RESTAURANT
# 27        Amity Multicuisine Restaurant               INDIAN RESTAURANT
# 28         Techies ( Solis ) Restaurant                            None
# 29  All Seasons Multicuisine Restaurant       MIDDLE EASTERN RESTAURANT
# 30                   Mallu's restaurant                            None
# 31                  Paradise Restaurant               INDIAN RESTAURANT
# 32                   Windows Restaurant                          ARCADE
# 33                    Mallus Restaurant               INDIAN RESTAURANT
# 34                       KFC restaurAnt                     WINGS JOINT
# 35              Messeleistro Restaurant                      RESTAURANT
# 36              swarna taara restaurant               INDIAN RESTAURANT
# 40     22     7.2               Indian Restaurants    False
# 41      0     0.0              Chinese Restaurants    False
# 42      0     0.0               Indian Restaurants    False
# 43      4     0.0                Asian Restaurants    False
# 44      0     0.0               Andhra Restaurants    False
# 45      0     0.0               Indian Restaurants    False
# 46      1     0.0              Chinese Restaurants    False
# 47      0     0.0               Indian Restaurants    False
# 48      0     0.0                      Restaurants    False
# 49      0     0.0                Asian Restaurants    False

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# ## 2. Explore a Given Venue
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# ### A. Let's explore the closest Italian restaurant -- _Harry's Italian Pizza Bar_

# %% [markdown]
# #### Send GET request for result

# %% [markdown]
# ### B. Get the venue's overall rating

# %% [markdown]
# That is not a very good rating. Let's check the rating of the second closest Italian restaurant.

# %% [markdown]
# Since this restaurant has no ratings, let's check the third restaurant.

# %% [markdown]
# Since this restaurant has a slightly better rating, let's explore it further.

# %% [markdown]
# ### C. Get the number of tips

# %% [markdown]
# ### D. Get the venue's tips
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`/tips?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### Create URL and send GET request. Make sure to set limit to get all tips

# %% [markdown]
# #### Get tips and list of associated features

# %% [markdown]
# #### Format column width and display all tips

# %% [markdown]
# Now remember that because we are using a personal developer account, then we can access only 2 of the restaurant's tips, instead of all 15 tips.

# %% [markdown]
# <a id="item3"></a>

# %% [markdown]
# ## 3. Search a Foursquare User
# > `https://api.foursquare.com/v2/users/`**USER_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# ### Define URL, send GET request and display features associated with user

# %% [markdown]
# #### How many tips has this user submitted?

# %% [markdown]
# Wow! So it turns out that Nick is a very active Foursquare user, with more than 250 tips.

# %% [markdown]
# ### Get User's tips

# %% [markdown]
# #### Let's get the venue for the tip with the greatest number of agree counts

# %% [markdown]
# ### Get User's friends

# %% [markdown]
# Interesting. Despite being very active, it turns out that Nick does not have any friends on Foursquare. This might definitely change in the future.

# %% [markdown]
# ### Retrieve the User's Profile Image

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# ## 4. Explore a location
# > `https://api.foursquare.com/v2/venues/`**explore**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### So, you just finished your gourmet dish at Ecco, and are just curious about the popular spots around the restaurant. In order to explore the area, let's start by getting the latitude and longitude values of Ecco Restaurant.

# %% [markdown]
# #### Define URL

# %% [markdown]
# #### Send GET request and examine results

# %% [markdown]
# #### Get relevant part of JSON

# %% [markdown]
# #### Process JSON and convert it to a clean dataframe

# %% [markdown]
# #### Let's visualize these items on the map around our location

# %% [markdown]
# <a id="item5"></a>

# %% [markdown]
# ## 5. Explore Trending Venues
# > `https://api.foursquare.com/v2/venues/`**trending**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**

# %% [markdown]
# #### Now, instead of simply exploring the area around Ecco, you are interested in knowing the venues that are trending at the time you are done with your lunch, meaning the places with the highest foot traffic. So let's do that and get the trending venues around Ecco.

# %% [markdown]
# ### Check if any venues are trending at this time

# %% [markdown]
# Now, depending on when you run the above code, you might get different venues since the venues with the highest foot traffic are fetched live.

# %% [markdown]
# ### Visualize trending venues

# %% [markdown]
# <a id="item6"></a>

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# This notebook is part of a course on **Coursera** called *Applied Data Science Capstone*. If you accessed this notebook outside the course, you can take this course online by clicking [here](http://cocl.us/DP0701EN_Coursera_Week2_LAB1).

# %% [markdown]
# <hr>
# Copyright &copy; 2018 [Cognitive Class](https://cognitiveclass.ai/?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).
